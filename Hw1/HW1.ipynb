# %% [markdown]
# ### Question 2.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x=np.arange(start=-100,stop=100,step=.1)

# %%
a1=20
b1=10

a2=-20
b2=10

px_1=np.exp(-np.abs(x-a1)/b1)
px_2=np.exp(-np.abs(x-a2)/b2)

# %%
plt.plot(x,px_1)
plt.plot(x,px_2)

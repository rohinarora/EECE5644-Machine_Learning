# %% [markdown]
# ![title](2.png)

# %% [markdown]
# ## Code accompanying question 2 of homework 1.

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import math

# %%
x=np.linspace(-10,10,num=100000)
f_x=.5*np.abs(x-1)-np.abs(x)+math.log(2) # l(x) in part 2 of question 2
fig = plt.figure(figsize=(12,12));
fig.text(.15,0.025,txt,fontsize=15);
txt="Plot of log-likelihood ratio between 2 classes with equi probable priors and with class \n conditional probabilities given by modified exponential distribution "
plt.plot(x,f_x,label='log-likelihood ratio');
plt.title('Plot of log-likelihood ratio',fontsize=15)
plt.xlabel('Random Variable X',fontsize=12)
plt.ylabel('l(x)',fontsize=12);
plt.legend()
plt.show()

# %% [markdown]
# ### Appendix.
#
# Conditonal Probability is symmetric. Hence integral to positive infinity will be 1/2

# %%
'''
User input. Enter any value of a
'''

a=10
b=1

# %%
x=np.linspace(-50,50,num=10000)
f_x=np.exp(-np.abs(x-a)/b)

# %%
plt.plot(x,f_x)

print ('Symmetric function around a')
# Out:
# Symmetric function around a
